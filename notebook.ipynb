# %%
import os

# %%
# %pwd
# Out:
# 'C:\\Users\\Gordts-De Laender\\Desktop\\Papa\\OU\\Capita\\Opdracht\\Opdracht3_DLIdea011_DLAssignment0602\\CapitaSelectaStargan'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5086-B9E3
#
#  Directory of C:\Users\Gordts-De Laender\Desktop\Papa\OU\Capita\Opdracht\Opdracht3_DLIdea011_DLAssignment0602\CapitaSelectaStargan
#
# 05/12/2024  18:04    <DIR>          .
# 05/12/2024  17:22    <DIR>          ..
# 05/12/2024  17:24    <DIR>          .ipynb_checkpoints
# 05/12/2024  18:00             3.304 notebook.ipynb
# 05/12/2024  17:22             2.440 README.md
# 05/12/2024  18:00    <DIR>          thumbnails128x128
#                2 File(s)          5.744 bytes
#                4 Dir(s)  82.084.483.072 bytes free

# %%
# !git clone https://github.com/yunjey/StarGAN.git
# Out:
# Cloning into 'StarGAN'...

# %%
# When running in windows open download.sh. in VS Code:
# Look for an indicator at the bottom-right of the editor (it might say "CRLF").
# Click on it and select "LF" (Line Feed) for Unix-style endings and save the file
# Make sure that the unzip utility is installed in your WSL environment
# !bash ./StarGAN/download.sh pretrained-celeba-128x128
# The bash command downloads StarGAN trained on CelebA (Black_Hair, Blond_Hair, Brown_Hair, Male, Young), 128x128 resolution. 
# The pre-trained model checkpoint will be downloaded and saved into ./stargan_celeba_128/models directory.
# Out:
# Archive:  ./stargan_celeba_128/models/celeba-128x128-5attrs.zip
#   inflating: ./stargan_celeba_128/models/200000-G.ckpt
#   inflating: ./stargan_celeba_128/models/200000-D.ckpt
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2024-12-05 18:20:03--  https://www.dropbox.com/s/7e966qq0nlxwte4/celeba-128x128-5attrs.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.65.18, 2620:100:6021:18::a27d:4112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.65.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/08n4ltopu9i91m4vqkknz/celeba-128x128-5attrs.zip?rlkey=msbqr4azhf50hl53cvosfqdy8&dl=0 [following]
# --2024-12-05 18:20:03--  https://www.dropbox.com/scl/fi/08n4ltopu9i91m4vqkknz/celeba-128x128-5attrs.zip?rlkey=msbqr4azhf50hl53cvosfqdy8&dl=0
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Training of StarGAN on the FFHQ dataset ==> create a folder structure in the same format as RaFD 
# as shown in https://github.com/yunjey/StarGAN/blob/master/jpg/RaFD.md
# %run ./StarGan/main.py --mode train --dataset FFHQ --rafd_crop_size CROP_SIZE --image_size IMG_SIZE \
               --c_dim LABEL_DIM --rafd_image_dir TRAIN_IMG_DIR \
               --sample_dir stargan_custom/samples --log_dir stargan_custom/logs \
               --model_save_dir stargan_custom/models --result_dir stargan_custom/results

# %%
# Testing of StarGAN on the FFHQ dataset 
# %run ./StarGan/main.py  --mode test --dataset FFHQ --rafd_crop_size CROP_SIZE --image_size IMG_SIZE \
               --c_dim LABEL_DIM --rafd_image_dir TEST_IMG_DIR \
               --sample_dir stargan_custom/samples --log_dir stargan_custom/logs \
               --model_save_dir stargan_custom/models --result_dir stargan_custom/results
